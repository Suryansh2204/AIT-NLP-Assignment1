# %% [markdown]
# # GloVE
#
# Let's work on implementation of GloVE.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Load data

# %%
import nltk
from nltk.corpus import semcor

nltk.download('semcor')
# Out:
# [nltk_data] Downloading package semcor to
# [nltk_data]     C:\Users\surya\AppData\Roaming\nltk_data...
# [nltk_data]   Package semcor is already up-to-date!
# True

# %%
#1. tokenization
corpus = semcor.sents()

# %%
#get word sequences and unique words
flatten = lambda l: [item for sublist in l for item in sublist]
vocab = list(set(flatten(corpus)))
vocab
# Out:
# ['kept',
#  'gate',
#  'featured',
#  'servants',
#  'roots',
#  'clerk',
#  'Black',
#  'partial',
#  "o'clock",
#  'chairs',
#  'Ca',
#  'observers',
#  'concerning',
#  'proof',
#  'disposed',
#  'wages',
#  'machine',
#  'Masters',
#  'alone',
#  'output',
#  'masses',
#  'owner',
#  'Day',
#  'peak',
#  'worth',
#  'line',
#  'female',
#  'Trig',
#  'consciously',
#  'Quite',
#  'walking',
#  'technology',
#  'connections',
#  'permits',
#  'Greg',
#  'least',
#  'shadows',
#  'boots',
#  'parents',
#  'Country',
#  'prevent',
#  'per',
#  'pilot',
#  'rank',
#  'preceded',
#  'staring',
#  'advocate',
#  'territorial',
#  'tune',
#  '1958',
#  'delay',
#  'strand',
#  'Beyond',
#  'stem',
#  'tube',
#  'appearing',
#  'stretch',
#  'brains',
#  'doctrine',
#  'square',
#  'proclaimed',
#  'Congolese',
#  'mere',
#  'sources',
#  'swiftly',
#  'Russian',
#  'combat',
#  'technical',
#  'official',
#  'wealth',
#  'fool',
#  '50',
#  'workshop',
#  'mountains',
#  'tailored',
#  'Southeast',
#  'caused',
#  'energetic',
#  'engines',
#  'spend',
#  'rocks',
#  'tangent',
#  'Go',
#  'Never',
#  'Force',
#  'shooting',
#  'events',
#  'Certain',
#  'accounts',
#  'classical',
#  'arrive',
#  'Du',
#  'symbolism',
#  'assumption',
#  'assert',
#  'reserve',
#  'loan',
#  'wall',
#  'depth',
#  'Oersted',
#  'milk',
#  'Colorado',
#  'Gilborn',
#  'fiscal',
#  'nation',
#  'meet',
#  'rent',
#  'regarding',
#  'lose',
#  'deserted',
#  'push',
#  'placed',
#  'biggest',
#  'repair',
#  'street',
#  'purchases',
#  'content',
#  'grounds',
#  'F',
#  'seen',
#  'actor',
#  'Clark',
#  'maturity',
#  'touching',
#  'punished',
#  'school',
#  'aim',
#  'Fire',
#  'nineteenth-century',
#  'formally',
#  'deliberately',
#  'writer',
#  'denomination',
#  'campaign',
#  'Kremlin',
#  'long-term',
#  'approximate',
#  'cows',
#  'bullet',
#  'Professor',
#  'discharge',
#  'threatening',
#  'tray',
#  'humor',
#  'burden',
#  'foremost',
#  'matters',
#  'planet',
#  'mg.',
#  'import',
#  'rifles',
#  'becoming',
#  'evidently',
#  'fiery',
#  'authorities',
#  'pump',
#  'pulls',
#  'interrupted',
#  'fit',
#  'salesmen',
#  'coat',
#  'Bonn',
#  'avoiding',
#  'beach',
#  'Harry',
#  'hear',
#  'Providence',
#  '80',
#  'ratings',
#  'acceptance',
#  'client',
#  'processes',
#  'relations',
#  'cleaning',
#  'along',
#  'name',
#  'Friends',
#  'entering',
#  'glorious',
#  'slug',
#  'Sometimes',
#  'volunteers',
#  'clinical',
#  'needs',
#  'learning',
#  'remove',
#  'terraces',
#  'working',
#  'superior',
#  'Blue',
#  'wisely',
#  'effects',
#  'commented',
#  'sister',
#  'news',
#  'lift',
#  'controls',
#  'deposited',
#  'Powell',
#  'truth',
#  'badly',
#  'skills',
#  'agency',
#  'well-being',
#  'wastes',
#  'Russians',
#  'Catholic',
#  'magic',
#  'materials',
#  'voters',
#  'advised',
#  'contest',
#  'runs',
#  'troops',
#  'Bake',
#  'measured',
#  'compared',
#  'lungs',
#  'severe',
#  'unnecessary',
#  'definitely',
#  'guard',
#  'nine',
#  'funds',
#  'Administration',
#  'ritual',
#  'neglected',
#  'country',
#  'usefulness',
#  'organize',
#  'registration',
#  'even',
#  'sea',
#  'Depot',
#  'unconscious',
#  'supper',
#  '1500',
#  'comments',
#  'tomorrow',
#  'Section',
#  'Matson',
#  'Hence',
#  'animals',
#  'Papa-san',
#  'gm.',
#  'interval',
#  'reserved',
#  'rack',
#  'Either',
#  'nowhere',
#  'house',
#  'lane',
#  'rule',
#  'temple',
#  '30',
#  'future',
#  'Springs',
#  'kitchen',
#  '1962',
#  'trip',
#  'placement',
#  'fearful',
#  'Accordingly',
#  'chicken',
#  'trail',
#  'mess',
#  'Warsaw',
#  'bedroom',
#  'knee',
#  'Fighting',
#  'coals',
#  'company',
#  'thigh',
#  'Conrad',
#  'moral',
#  'national',
#  'goods',
#  'Richmond',
#  'golf',
#  'walk',
#  'dogs',
#  'Presently',
#  'guarantees',
#  'heights',
#  'army',
#  'Finally',
#  'instrument',
#  'different',
#  'intention',
#  'attempting',
#  'chambers',
#  'shall',
#  'justice',
#  'Gardens',
#  'becomes',
#  'opens',
#  'diminished',
#  'proposed',
#  'represent',
#  'train',
#  'considerable',
#  'avocado',
#  'outcomes',
#  'union',
#  'Death',
#  'agreed',
#  'Besides',
#  'clue',
#  'shame',
#  'shoulders',
#  'H.',
#  'luncheon',
#  'earning',
#  'witness',
#  'force',
#  'specialists',
#  'gives',
#  'blooming',
#  'resolved',
#  'score',
#  'pertinent',
#  'teaching',
#  'nerve',
#  'message',
#  'place',
#  'involution',
#  'Flannagan',
#  'creates',
#  'add',
#  'lawyer',
#  'theological',
#  'wood',
#  'cannot',
#  'specific',
#  'Daniel',
#  'south',
#  'threatened',
#  'assign',
#  'alive',
#  'mining',
#  'dreadful',
#  'Pam',
#  'automobile',
#  'principle',
#  'Foods',
#  'forgiveness',
#  'impersonal',
#  'promised',
#  'Keys',
#  'middle',
#  'single',
#  'maker',
#  'l',
#  'fists',
#  'stirred',
#  'task',
#  'parked',
#  'weary',
#  'Cranston',
#  'clarity',
#  'fixed',
#  'upright',
#  'sun',
#  'Lee',
#  'Fund',
#  'superstition',
#  'commanded',
#  'adults',
#  'Others',
#  'mathematical',
#  'tanks',
#  'pot',
#  'conceive',
#  'guide',
#  'prospects',
#  'Capone',
#  'forces',
#  'airfields',
#  'advice',
#  'draped',
#  'increases',
#  'butter',
#  'districts',
#  'Also',
#  'O.',
#  'rags',
#  'block',
#  'send',
#  'African',
#  '65',
#  'cotton',
#  'shipping',
#  'lands',
#  'earth',
#  'display',
#  'briefly',
#  'Pa',
#  'succeeded',
#  'huge',
#  'Pastern',
#  'Kahler',
#  'sketch',
#  'spirit',
#  'Sergeant',
#  'debate',
#  'nursery',
#  'hat',
#  'slightest',
#  'amounts',
#  'inner',
#  'engineer',
#  'fig.',
#  'arched',
#  'tooth',
#  'nuclear',
#  'heart',
#  'power',
#  '34',
#  'conducted',
#  'equation',
#  'Apparently',
#  'sweat',
#  'Moliere',
#  'Perhaps',
#  'p',
#  'collecting',
#  'delivering',
#  'Council',
#  'conference',
#  'horse',
#  'seemingly',
#  'carriers',
#  'heaven',
#  'talks',
#  'baked',
#  'appeals',
#  'presence',
#  'causes',
#  'afternoons',
#  'Jews',
#  'domination',
#  'survive',
#  'everyone',
#  'decades',
#  'jam',
#  'theologians',
#  'attached',
#  'graph',
#  'fees',
#  'series',
#  'census',
#  'hated',
#  'Madden',
#  'regular',
#  'rot',
#  'breath',
#  'congregation',
#  'authors',
#  '28',
#  '11',
#  'wars',
#  'ages',
#  'platoon',
#  'consistency',
#  'fled',
#  'unusually',
#  'asserted',
#  'supposed',
#  'cement',
#  'completed',
#  'Pamela',
#  'appealing',
#  'Skyros',
#  'artists',
#  'bartender',
#  "'re",
#  'residents',
#  'Napoleon',
#  'films',
#  'words',
#  'scale',
#  'Special',
#  'foot',
#  'nutrition',
#  'ultimate',
#  'guns',
#  'Communists',
#  'sprang',
#  'spreading',
#  'closely',
#  'U',
#  'Fathers',
#  'tactics',
#  'Barton',
#  'Junior',
#  'exchange',
#  'P.',
#  'Ireland',
#  'noble',
#  'stove',
#  'Greenwich',
#  'commission',
#  'momentum',
#  'plowing',
#  'pastors',
#  'crown',
#  'Bishop',
#  'glued',
#  'doorway',
#  'Clayton',
#  'polished',
#  'neither',
#  'poured',
#  'Marine',
#  'hesitated',
#  'Ferguson',
#  'youngest',
#  'bought',
#  'straightened',
#  'remember',
#  'sensitive',
#  'clearer',
#  'policies',
#  'late',
#  'waited',
#  'University',
#  'items',
#  'Rogers',
#  'Geneva',
#  'dikkat',
#  'persisted',
#  'shapes',
#  'tends',
#  'crashed',
#  'arrived',
#  'livestock',
#  'feelings',
#  'Lord',
#  'Northern',
#  'nose',
#  'meeting',
#  'suits',
#  'sense',
#  'Pittsburgh',
#  'producer',
#  'financially',
#  'Anglican',
#  'kicked',
#  'White',
#  'Orchestra',
#  'pleading',
#  'Earth',
#  'pretending',
#  'avoided',
#  'normally',
#  'unexpected',
#  'swim',
#  'agencies',
#  'straw',
#  'cutting',
#  'gently',
#  'SAC',
#  'week',
#  'helping',
#  'swift',
#  'daylight',
#  'innocent',
#  'displacement',
#  'hearing',
#  'Southern',
#  'right',
#  'eccentric',
#  '10',
#  'symbols',
#  'however',
#  'fitting',
#  'adjustment',
#  'adjusting',
#  'Japan',
#  'portion',
#  'trusted',
#  'lousy',
#  'realize',
#  'fork',
#  'pressure',
#  'standing',
#  'guests',
#  'alternate',
#  'encounter',
#  'Completion',
#  'Reverend',
#  'tree',
#  'beginning',
#  'mad',
#  'medical',
#  'North',
#  'people',
#  'p.',
#  'Joel',
#  'partners',
#  'patterns',
#  'admiration',
#  'veto',
#  'legal',
#  'marked',
#  'orientation',
#  'American',
#  'conscientious',
#  'procedures',
#  'breaking',
#  'members',
#  'philosophy',
#  'Temple',
#  'Island',
#  'dresses',
#  'Methodist',
#  'knowledge',
#  'memories',
#  'lay',
#  'Negroes',
#  '40000',
#  'Heaven',
#  'compare',
#  'Elizabeth',
#  'stained',
#  'museum',
#  'Journal',
#  'Kohnstamm',
#  'flooded',
#  'gifts',
#  'obtaining',
#  'pains',
#  'Australia',
#  'Morton',
#  'printed',
#  'drops',
#  'command',
#  'DEAE-cellulose',
#  'reliable',
#  'replaced',
#  'grown',
#  'projects',
#  'International',
#  'sit',
#  'tropical',
#  'continuously',
#  'credited',
#  'happen',
#  'steadily',
#  'Southwest',
#  'visit',
#  'Every',
#  'secretary',
#  'dancer',
#  'beatnik',
#  'Louis',
#  '6',
#  'scholarship',
#  'forty',
#  'carefully',
#  'threats',
#  'president',
#  'organic',
#  'animal',
#  'adopted',
#  'failing',
#  'paused',
#  '58',
#  'hundreds',
#  'hut',
#  'graduation',
#  'television',
#  'revenue',
#  'heard',
#  'relationship',
#  'supreme',
#  'appearances',
#  'exhibits',
#  'orbit',
#  'shoved',
#  'demographic',
#  'claimed',
#  'insights',
#  'courts',
#  'invitations',
#  'separation',
#  'satisfy',
#  'victims',
#  'equal',
#  'sponsors',
#  'killed',
#  'smile',
#  'Bar',
#  'investors',
#  'builders',
#  'Bears',
#  'directors',
#  'whip',
#  'tests',
#  'expedition',
#  'Picasso',
#  'Cologne',
#  'match',
#  'hurry',
#  'Valley',
#  'welcomed',
#  'slipped',
#  'Word',
#  'economic',
#  'agent',
#  'pan',
#  'streams',
#  'violin',
#  'moved',
#  'way',
#  'farther',
#  'silent',
#  'proposal',
#  'picking',
#  'cherished',
#  'hand',
#  'River',
#  'cooler',
#  'surely',
#  'differentiation',
#  'administrative',
#  'prevention',
#  'implicit',
#  'medicine',
#  'suburban',
#  'twist',
#  'transducer',
#  'acts',
#  'limp',
#  'Otherwise',
#  'talents',
#  'deserved',
#  'overnight',
#  'Missouri',
#  'Billy',
#  'ranks',
#  'Middle',
#  'discourage',
#  'followed',
#  'passion',
#  'faculty',
#  'January',
#  'outboard',
#  'stage',
#  'purpose',
#  'danger',
#  'Eileen',
#  'resulting',
#  'coupled',
#  'formulated',
#  'terribly',
#  '1930',
#  'Larkin',
#  'dependent',
#  'cooling',
#  'request',
#  'function',
#  'justified',
#  'belongs',
#  'changed',
#  'copies',
#  'roll',
#  'incredibly',
#  'Scott',
#  'tsunami',
#  'burned',
#  'resident',
#  'mentally',
#  'story',
#  'wild',
#  'rushed',
#  'salvation',
#  'prestige',
#  'tearing',
#  'grin',
#  '1944',
#  'reporter',
#  'angle',
#  'group',
#  'Society',
#  'dropping',
#  'nature',
#  'sitter',
#  'storage',
#  'York',
#  'playing',
#  'fingers',
#  'Westminster',
#  'children',
#  'administration',
#  'Q',
#  'label',
#  'sincere',
#  'poem',
#  'beebread',
#  'climbed',
#  'London',
#  'enormous',
#  'yielded',
#  'elephants',
#  'thyroid',
#  'victim',
#  'TSH',
#  'dried',
#  'distribution',
#  'v.',
#  'first',
#  'sturdy',
#  'Biblical',
#  'cope',
#  'facts',
#  'instrumental',
#  '3000',
#  'one',
#  'past',
#  'backs',
#  'discover',
#  'peas',
#  'handed',
#  'undoubtedly',
#  'returning',
#  'deaf',
#  '26',
#  'makes',
#  'core',
#  'turnpikes',
#  'independently',
#  'binomial',
#  'assistant',
#  'divisions',
#  'see',
#  'letting',
#  'Doctor',
#  'growing',
#  'hands',
#  'Premier',
#  'Barnett',
#  'Dallas',
#  'Indeed',
#  'legitimate',
#  'oriented',
#  'missions',
#  'dangers',
#  'latest',
#  'Atlantic',
#  'fundamental',
#  'anyhow',
#  'masterpiece',
#  'piece',
#  'Alfred',
#  'protective',
#  'guilty',
#  'whiskey',
#  'opening',
#  'given',
#  'singers',
#  'convenient',
#  'struggling',
#  'site',
#  'uncertainty',
#  'portable',
#  'H',
#  'wound',
#  'told',
#  'instantly',
#  'gentleman',
#  'unfair',
#  'carry',
#  'temperature',
#  'sentences',
#  'attorney',
#  'rock',
#  'comment',
#  'Islands',
#  'Giants',
#  'replacement',
#  'obliged',
#  'exports',
#  'necessarily',
#  'producers',
#  'print',
#  'muddy',
#  'Figure',
#  'sales',
#  'Beckett',
#  'vigor',
#  'observer',
#  'networks',
#  'utterly',
#  'result',
#  'going',
#  'develops',
#  'cooperative',
#  'service',
#  'Shayne',
#  'professor',
#  'absolute',
#  'fog',
#  'barn',
#  'cure',
#  'commitments',
#  'stay',
#  'bomb',
#  'baby',
#  'war',
#  'qualified',
#  'quarrel',
#  'Men',
#  'guilt',
#  'thoroughly',
#  'handling',
#  'west',
#  'females',
#  'ranch',
#  'dome',
#  'reduction',
#  'brief',
#  'destroyed',
#  'dry',
#  'Cavalry',
#  'marching',
#  'took',
#  'clergyman',
#  'purity',
#  'meaningless',
#  'queens',
#  'vision',
#  'bunks',
#  'capitalism',
#  'W.',
#  'Carl',
#  'body',
#  'stretched',
#  'assure',
#  'physics',
#  'mild',
#  'include',
#  'hormone',
#  'experimental',
#  'Shea',
#  'artist',
#  'prone',
#  'intend',
#  'triumph',
#  'accuracy',
#  'repeatedly',
#  'tetrachloride',
#  'comparative',
#  'peaceful',
#  'Wagner',
#  'tracing',
#  'entry',
#  'surprised',
#  'prominent',
#  'starting',
#  'traditions',
#  'minute',
#  'tossed',
#  'Pohl',
#  'apprehension',
#  'section',
#  'cap',
#  'epidemic',
#  'year-old',
#  'radio',
#  'pine',
#  'elsewhere',
#  'Room',
#  'spare',
#  'legislators',
#  'vote',
#  'dominance',
#  'fellowship',
#  'testimony',
#  'conditioned',
#  'statement',
#  'games',
#  'polls',
#  'various',
#  'fences',
#  'border',
#  'specified',
#  'prepare',
#  'unemployment',
#  'appreciation',
#  'dignity',
#  'bag',
#  'sidewalk',
#  'Defense',
#  'esprit',
#  'fishing',
#  'accurate',
#  'conduct',
#  'changing',
#  'exposure',
#  ...]

# %%
#numericalization
word2index = {w: i for i, w in enumerate(vocab)}
print(word2index)
# Out:
# {'kept': 0, 'gate': 1, 'featured': 2, 'servants': 3, 'roots': 4, 'clerk': 5, 'Black': 6, 'partial': 7, "o'clock": 8, 'chairs': 9, 'Ca': 10, 'observers': 11, 'concerning': 12, 'proof': 13, 'disposed': 14, 'wages': 15, 'machine': 16, 'Masters': 17, 'alone': 18, 'output': 19, 'masses': 20, 'owner': 21, 'Day': 22, 'peak': 23, 'worth': 24, 'line': 25, 'female': 26, 'Trig': 27, 'consciously': 28, 'Quite': 29, 'walking': 30, 'technology': 31, 'connections': 32, 'permits': 33, 'Greg': 34, 'least': 35, 'shadows': 36, 'boots': 37, 'parents': 38, 'Country': 39, 'prevent': 40, 'per': 41, 'pilot': 42, 'rank': 43, 'preceded': 44, 'staring': 45, 'advocate': 46, 'territorial': 47, 'tune': 48, '1958': 49, 'delay': 50, 'strand': 51, 'Beyond': 52, 'stem': 53, 'tube': 54, 'appearing': 55, 'stretch': 56, 'brains': 57, 'doctrine': 58, 'square': 59, 'proclaimed': 60, 'Congolese': 61, 'mere': 62, 'sources': 63, 'swiftly': 64, 'Russian': 65, 'combat': 66, 'technical': 67, 'official': 68, 'wealth': 69, 'fool': 70, '50': 71, 'workshop': 72, 'mountains': 73, 'tailored': 74, 'Southeast': 75, 'caused': 76, 'energetic': 77, 'engines': 78, 'spend': 79, 'rocks': 80, 'tangent': 81, 'Go': 82, 'Never': 83, 'Force': 84, 'shooting': 85, 'events': 86, 'Certain': 87, 'accounts': 88, 'classical': 89, 'arrive': 90, 'Du': 91, 'symbolism': 92, 'assumption': 93, 'assert': 94, 'reserve': 95, 'loan': 96, 'wall': 97, 'depth': 98, 'Oersted': 99, 'milk': 100, 'Colorado': 101, 'Gilborn': 102, 'fiscal': 103, 'nation': 104, 'meet': 105, 'rent': 106, 'regarding': 107, 'lose': 108, 'deserted': 109, 'push': 110, 'placed': 111, 'biggest': 112, 'repair': 113, 'street': 114, 'purchases': 115, 'content': 116, 'grounds': 117, 'F': 118, 'seen': 119, 'actor': 120, 'Clark': 121, 'maturity': 122, 'touching': 123, 'punished': 124, 'school': 125, 'aim': 126, 'Fire': 127, 'nineteenth-century': 128, 'formally': 129, 'deliberately': 130, 'writer': 131, 'denomination': 132, 'campaign': 133, 'Kremlin': 134, 'long-term': 135, 'approximate': 136, 'cows': 137, 'bullet': 138, 'Professor': 139, 'discharge': 140, 'threatening': 141, 'tray': 142, 'humor': 143, 'burden': 144, 'foremost': 145, 'matters': 146, 'planet': 147, 'mg.': 148, 'import': 149, 'rifles': 150, 'becoming': 151, 'evidently': 152, 'fiery': 153, 'authorities': 154, 'pump': 155, 'pulls': 156, 'interrupted': 157, 'fit': 158, 'salesmen': 159, 'coat': 160, 'Bonn': 161, 'avoiding': 162, 'beach': 163, 'Harry': 164, 'hear': 165, 'Providence': 166, '80': 167, 'ratings': 168, 'acceptance': 169, 'client': 170, 'processes': 171, 'relations': 172, 'cleaning': 173, 'along': 174, 'name': 175, 'Friends': 176, 'entering': 177, 'glorious': 178, 'slug': 179, 'Sometimes': 180, 'volunteers': 181, 'clinical': 182, 'needs': 183, 'learning': 184, 'remove': 185, 'terraces': 186, 'working': 187, 'superior': 188, 'Blue': 189, 'wisely': 190, 'effects': 191, 'commented': 192, 'sister': 193, 'news': 194, 'lift': 195, 'controls': 196, 'deposited': 197, 'Powell': 198, 'truth': 199, 'badly': 200, 'skills': 201, 'agency': 202, 'well-being': 203, 'wastes': 204, 'Russians': 205, 'Catholic': 206, 'magic': 207, 'materials': 208, 'voters': 209, 'advised': 210, 'contest': 211, 'runs': 212, 'troops': 213, 'Bake': 214, 'measured': 215, 'compared': 216, 'lungs': 217, 'severe': 218, 'unnecessary': 219, 'definitely': 220, 'guard': 221, 'nine': 222, 'funds': 223, 'Administration': 224, 'ritual': 225, 'neglected': 226, 'country': 227, 'usefulness': 228, 'organize': 229, 'registration': 230, 'even': 231, 'sea': 232, 'Depot': 233, 'unconscious': 234, 'supper': 235, '1500': 236, 'comments': 237, 'tomorrow': 238, 'Section': 239, 'Matson': 240, 'Hence': 241, 'animals': 242, 'Papa-san': 243, 'gm.': 244, 'interval': 245, 'reserved': 246, 'rack': 247, 'Either': 248, 'nowhere': 249, 'house': 250, 'lane': 251, 'rule': 252, 'temple': 253, '30': 254, 'future': 255, 'Springs': 256, 'kitchen': 257, '1962': 258, 'trip': 259, 'placement': 260, 'fearful': 261, 'Accordingly': 262, 'chicken': 263, 'tra ...

# %%
#vocab size
voc_size = len(vocab)
print(voc_size)
# Out:
# 8141

# %%
#append UNK
vocab.append('<UNK>')

# %%
vocab
# Out:
# ['kept',
#  'gate',
#  'featured',
#  'servants',
#  'roots',
#  'clerk',
#  'Black',
#  'partial',
#  "o'clock",
#  'chairs',
#  'Ca',
#  'observers',
#  'concerning',
#  'proof',
#  'disposed',
#  'wages',
#  'machine',
#  'Masters',
#  'alone',
#  'output',
#  'masses',
#  'owner',
#  'Day',
#  'peak',
#  'worth',
#  'line',
#  'female',
#  'Trig',
#  'consciously',
#  'Quite',
#  'walking',
#  'technology',
#  'connections',
#  'permits',
#  'Greg',
#  'least',
#  'shadows',
#  'boots',
#  'parents',
#  'Country',
#  'prevent',
#  'per',
#  'pilot',
#  'rank',
#  'preceded',
#  'staring',
#  'advocate',
#  'territorial',
#  'tune',
#  '1958',
#  'delay',
#  'strand',
#  'Beyond',
#  'stem',
#  'tube',
#  'appearing',
#  'stretch',
#  'brains',
#  'doctrine',
#  'square',
#  'proclaimed',
#  'Congolese',
#  'mere',
#  'sources',
#  'swiftly',
#  'Russian',
#  'combat',
#  'technical',
#  'official',
#  'wealth',
#  'fool',
#  '50',
#  'workshop',
#  'mountains',
#  'tailored',
#  'Southeast',
#  'caused',
#  'energetic',
#  'engines',
#  'spend',
#  'rocks',
#  'tangent',
#  'Go',
#  'Never',
#  'Force',
#  'shooting',
#  'events',
#  'Certain',
#  'accounts',
#  'classical',
#  'arrive',
#  'Du',
#  'symbolism',
#  'assumption',
#  'assert',
#  'reserve',
#  'loan',
#  'wall',
#  'depth',
#  'Oersted',
#  'milk',
#  'Colorado',
#  'Gilborn',
#  'fiscal',
#  'nation',
#  'meet',
#  'rent',
#  'regarding',
#  'lose',
#  'deserted',
#  'push',
#  'placed',
#  'biggest',
#  'repair',
#  'street',
#  'purchases',
#  'content',
#  'grounds',
#  'F',
#  'seen',
#  'actor',
#  'Clark',
#  'maturity',
#  'touching',
#  'punished',
#  'school',
#  'aim',
#  'Fire',
#  'nineteenth-century',
#  'formally',
#  'deliberately',
#  'writer',
#  'denomination',
#  'campaign',
#  'Kremlin',
#  'long-term',
#  'approximate',
#  'cows',
#  'bullet',
#  'Professor',
#  'discharge',
#  'threatening',
#  'tray',
#  'humor',
#  'burden',
#  'foremost',
#  'matters',
#  'planet',
#  'mg.',
#  'import',
#  'rifles',
#  'becoming',
#  'evidently',
#  'fiery',
#  'authorities',
#  'pump',
#  'pulls',
#  'interrupted',
#  'fit',
#  'salesmen',
#  'coat',
#  'Bonn',
#  'avoiding',
#  'beach',
#  'Harry',
#  'hear',
#  'Providence',
#  '80',
#  'ratings',
#  'acceptance',
#  'client',
#  'processes',
#  'relations',
#  'cleaning',
#  'along',
#  'name',
#  'Friends',
#  'entering',
#  'glorious',
#  'slug',
#  'Sometimes',
#  'volunteers',
#  'clinical',
#  'needs',
#  'learning',
#  'remove',
#  'terraces',
#  'working',
#  'superior',
#  'Blue',
#  'wisely',
#  'effects',
#  'commented',
#  'sister',
#  'news',
#  'lift',
#  'controls',
#  'deposited',
#  'Powell',
#  'truth',
#  'badly',
#  'skills',
#  'agency',
#  'well-being',
#  'wastes',
#  'Russians',
#  'Catholic',
#  'magic',
#  'materials',
#  'voters',
#  'advised',
#  'contest',
#  'runs',
#  'troops',
#  'Bake',
#  'measured',
#  'compared',
#  'lungs',
#  'severe',
#  'unnecessary',
#  'definitely',
#  'guard',
#  'nine',
#  'funds',
#  'Administration',
#  'ritual',
#  'neglected',
#  'country',
#  'usefulness',
#  'organize',
#  'registration',
#  'even',
#  'sea',
#  'Depot',
#  'unconscious',
#  'supper',
#  '1500',
#  'comments',
#  'tomorrow',
#  'Section',
#  'Matson',
#  'Hence',
#  'animals',
#  'Papa-san',
#  'gm.',
#  'interval',
#  'reserved',
#  'rack',
#  'Either',
#  'nowhere',
#  'house',
#  'lane',
#  'rule',
#  'temple',
#  '30',
#  'future',
#  'Springs',
#  'kitchen',
#  '1962',
#  'trip',
#  'placement',
#  'fearful',
#  'Accordingly',
#  'chicken',
#  'trail',
#  'mess',
#  'Warsaw',
#  'bedroom',
#  'knee',
#  'Fighting',
#  'coals',
#  'company',
#  'thigh',
#  'Conrad',
#  'moral',
#  'national',
#  'goods',
#  'Richmond',
#  'golf',
#  'walk',
#  'dogs',
#  'Presently',
#  'guarantees',
#  'heights',
#  'army',
#  'Finally',
#  'instrument',
#  'different',
#  'intention',
#  'attempting',
#  'chambers',
#  'shall',
#  'justice',
#  'Gardens',
#  'becomes',
#  'opens',
#  'diminished',
#  'proposed',
#  'represent',
#  'train',
#  'considerable',
#  'avocado',
#  'outcomes',
#  'union',
#  'Death',
#  'agreed',
#  'Besides',
#  'clue',
#  'shame',
#  'shoulders',
#  'H.',
#  'luncheon',
#  'earning',
#  'witness',
#  'force',
#  'specialists',
#  'gives',
#  'blooming',
#  'resolved',
#  'score',
#  'pertinent',
#  'teaching',
#  'nerve',
#  'message',
#  'place',
#  'involution',
#  'Flannagan',
#  'creates',
#  'add',
#  'lawyer',
#  'theological',
#  'wood',
#  'cannot',
#  'specific',
#  'Daniel',
#  'south',
#  'threatened',
#  'assign',
#  'alive',
#  'mining',
#  'dreadful',
#  'Pam',
#  'automobile',
#  'principle',
#  'Foods',
#  'forgiveness',
#  'impersonal',
#  'promised',
#  'Keys',
#  'middle',
#  'single',
#  'maker',
#  'l',
#  'fists',
#  'stirred',
#  'task',
#  'parked',
#  'weary',
#  'Cranston',
#  'clarity',
#  'fixed',
#  'upright',
#  'sun',
#  'Lee',
#  'Fund',
#  'superstition',
#  'commanded',
#  'adults',
#  'Others',
#  'mathematical',
#  'tanks',
#  'pot',
#  'conceive',
#  'guide',
#  'prospects',
#  'Capone',
#  'forces',
#  'airfields',
#  'advice',
#  'draped',
#  'increases',
#  'butter',
#  'districts',
#  'Also',
#  'O.',
#  'rags',
#  'block',
#  'send',
#  'African',
#  '65',
#  'cotton',
#  'shipping',
#  'lands',
#  'earth',
#  'display',
#  'briefly',
#  'Pa',
#  'succeeded',
#  'huge',
#  'Pastern',
#  'Kahler',
#  'sketch',
#  'spirit',
#  'Sergeant',
#  'debate',
#  'nursery',
#  'hat',
#  'slightest',
#  'amounts',
#  'inner',
#  'engineer',
#  'fig.',
#  'arched',
#  'tooth',
#  'nuclear',
#  'heart',
#  'power',
#  '34',
#  'conducted',
#  'equation',
#  'Apparently',
#  'sweat',
#  'Moliere',
#  'Perhaps',
#  'p',
#  'collecting',
#  'delivering',
#  'Council',
#  'conference',
#  'horse',
#  'seemingly',
#  'carriers',
#  'heaven',
#  'talks',
#  'baked',
#  'appeals',
#  'presence',
#  'causes',
#  'afternoons',
#  'Jews',
#  'domination',
#  'survive',
#  'everyone',
#  'decades',
#  'jam',
#  'theologians',
#  'attached',
#  'graph',
#  'fees',
#  'series',
#  'census',
#  'hated',
#  'Madden',
#  'regular',
#  'rot',
#  'breath',
#  'congregation',
#  'authors',
#  '28',
#  '11',
#  'wars',
#  'ages',
#  'platoon',
#  'consistency',
#  'fled',
#  'unusually',
#  'asserted',
#  'supposed',
#  'cement',
#  'completed',
#  'Pamela',
#  'appealing',
#  'Skyros',
#  'artists',
#  'bartender',
#  "'re",
#  'residents',
#  'Napoleon',
#  'films',
#  'words',
#  'scale',
#  'Special',
#  'foot',
#  'nutrition',
#  'ultimate',
#  'guns',
#  'Communists',
#  'sprang',
#  'spreading',
#  'closely',
#  'U',
#  'Fathers',
#  'tactics',
#  'Barton',
#  'Junior',
#  'exchange',
#  'P.',
#  'Ireland',
#  'noble',
#  'stove',
#  'Greenwich',
#  'commission',
#  'momentum',
#  'plowing',
#  'pastors',
#  'crown',
#  'Bishop',
#  'glued',
#  'doorway',
#  'Clayton',
#  'polished',
#  'neither',
#  'poured',
#  'Marine',
#  'hesitated',
#  'Ferguson',
#  'youngest',
#  'bought',
#  'straightened',
#  'remember',
#  'sensitive',
#  'clearer',
#  'policies',
#  'late',
#  'waited',
#  'University',
#  'items',
#  'Rogers',
#  'Geneva',
#  'dikkat',
#  'persisted',
#  'shapes',
#  'tends',
#  'crashed',
#  'arrived',
#  'livestock',
#  'feelings',
#  'Lord',
#  'Northern',
#  'nose',
#  'meeting',
#  'suits',
#  'sense',
#  'Pittsburgh',
#  'producer',
#  'financially',
#  'Anglican',
#  'kicked',
#  'White',
#  'Orchestra',
#  'pleading',
#  'Earth',
#  'pretending',
#  'avoided',
#  'normally',
#  'unexpected',
#  'swim',
#  'agencies',
#  'straw',
#  'cutting',
#  'gently',
#  'SAC',
#  'week',
#  'helping',
#  'swift',
#  'daylight',
#  'innocent',
#  'displacement',
#  'hearing',
#  'Southern',
#  'right',
#  'eccentric',
#  '10',
#  'symbols',
#  'however',
#  'fitting',
#  'adjustment',
#  'adjusting',
#  'Japan',
#  'portion',
#  'trusted',
#  'lousy',
#  'realize',
#  'fork',
#  'pressure',
#  'standing',
#  'guests',
#  'alternate',
#  'encounter',
#  'Completion',
#  'Reverend',
#  'tree',
#  'beginning',
#  'mad',
#  'medical',
#  'North',
#  'people',
#  'p.',
#  'Joel',
#  'partners',
#  'patterns',
#  'admiration',
#  'veto',
#  'legal',
#  'marked',
#  'orientation',
#  'American',
#  'conscientious',
#  'procedures',
#  'breaking',
#  'members',
#  'philosophy',
#  'Temple',
#  'Island',
#  'dresses',
#  'Methodist',
#  'knowledge',
#  'memories',
#  'lay',
#  'Negroes',
#  '40000',
#  'Heaven',
#  'compare',
#  'Elizabeth',
#  'stained',
#  'museum',
#  'Journal',
#  'Kohnstamm',
#  'flooded',
#  'gifts',
#  'obtaining',
#  'pains',
#  'Australia',
#  'Morton',
#  'printed',
#  'drops',
#  'command',
#  'DEAE-cellulose',
#  'reliable',
#  'replaced',
#  'grown',
#  'projects',
#  'International',
#  'sit',
#  'tropical',
#  'continuously',
#  'credited',
#  'happen',
#  'steadily',
#  'Southwest',
#  'visit',
#  'Every',
#  'secretary',
#  'dancer',
#  'beatnik',
#  'Louis',
#  '6',
#  'scholarship',
#  'forty',
#  'carefully',
#  'threats',
#  'president',
#  'organic',
#  'animal',
#  'adopted',
#  'failing',
#  'paused',
#  '58',
#  'hundreds',
#  'hut',
#  'graduation',
#  'television',
#  'revenue',
#  'heard',
#  'relationship',
#  'supreme',
#  'appearances',
#  'exhibits',
#  'orbit',
#  'shoved',
#  'demographic',
#  'claimed',
#  'insights',
#  'courts',
#  'invitations',
#  'separation',
#  'satisfy',
#  'victims',
#  'equal',
#  'sponsors',
#  'killed',
#  'smile',
#  'Bar',
#  'investors',
#  'builders',
#  'Bears',
#  'directors',
#  'whip',
#  'tests',
#  'expedition',
#  'Picasso',
#  'Cologne',
#  'match',
#  'hurry',
#  'Valley',
#  'welcomed',
#  'slipped',
#  'Word',
#  'economic',
#  'agent',
#  'pan',
#  'streams',
#  'violin',
#  'moved',
#  'way',
#  'farther',
#  'silent',
#  'proposal',
#  'picking',
#  'cherished',
#  'hand',
#  'River',
#  'cooler',
#  'surely',
#  'differentiation',
#  'administrative',
#  'prevention',
#  'implicit',
#  'medicine',
#  'suburban',
#  'twist',
#  'transducer',
#  'acts',
#  'limp',
#  'Otherwise',
#  'talents',
#  'deserved',
#  'overnight',
#  'Missouri',
#  'Billy',
#  'ranks',
#  'Middle',
#  'discourage',
#  'followed',
#  'passion',
#  'faculty',
#  'January',
#  'outboard',
#  'stage',
#  'purpose',
#  'danger',
#  'Eileen',
#  'resulting',
#  'coupled',
#  'formulated',
#  'terribly',
#  '1930',
#  'Larkin',
#  'dependent',
#  'cooling',
#  'request',
#  'function',
#  'justified',
#  'belongs',
#  'changed',
#  'copies',
#  'roll',
#  'incredibly',
#  'Scott',
#  'tsunami',
#  'burned',
#  'resident',
#  'mentally',
#  'story',
#  'wild',
#  'rushed',
#  'salvation',
#  'prestige',
#  'tearing',
#  'grin',
#  '1944',
#  'reporter',
#  'angle',
#  'group',
#  'Society',
#  'dropping',
#  'nature',
#  'sitter',
#  'storage',
#  'York',
#  'playing',
#  'fingers',
#  'Westminster',
#  'children',
#  'administration',
#  'Q',
#  'label',
#  'sincere',
#  'poem',
#  'beebread',
#  'climbed',
#  'London',
#  'enormous',
#  'yielded',
#  'elephants',
#  'thyroid',
#  'victim',
#  'TSH',
#  'dried',
#  'distribution',
#  'v.',
#  'first',
#  'sturdy',
#  'Biblical',
#  'cope',
#  'facts',
#  'instrumental',
#  '3000',
#  'one',
#  'past',
#  'backs',
#  'discover',
#  'peas',
#  'handed',
#  'undoubtedly',
#  'returning',
#  'deaf',
#  '26',
#  'makes',
#  'core',
#  'turnpikes',
#  'independently',
#  'binomial',
#  'assistant',
#  'divisions',
#  'see',
#  'letting',
#  'Doctor',
#  'growing',
#  'hands',
#  'Premier',
#  'Barnett',
#  'Dallas',
#  'Indeed',
#  'legitimate',
#  'oriented',
#  'missions',
#  'dangers',
#  'latest',
#  'Atlantic',
#  'fundamental',
#  'anyhow',
#  'masterpiece',
#  'piece',
#  'Alfred',
#  'protective',
#  'guilty',
#  'whiskey',
#  'opening',
#  'given',
#  'singers',
#  'convenient',
#  'struggling',
#  'site',
#  'uncertainty',
#  'portable',
#  'H',
#  'wound',
#  'told',
#  'instantly',
#  'gentleman',
#  'unfair',
#  'carry',
#  'temperature',
#  'sentences',
#  'attorney',
#  'rock',
#  'comment',
#  'Islands',
#  'Giants',
#  'replacement',
#  'obliged',
#  'exports',
#  'necessarily',
#  'producers',
#  'print',
#  'muddy',
#  'Figure',
#  'sales',
#  'Beckett',
#  'vigor',
#  'observer',
#  'networks',
#  'utterly',
#  'result',
#  'going',
#  'develops',
#  'cooperative',
#  'service',
#  'Shayne',
#  'professor',
#  'absolute',
#  'fog',
#  'barn',
#  'cure',
#  'commitments',
#  'stay',
#  'bomb',
#  'baby',
#  'war',
#  'qualified',
#  'quarrel',
#  'Men',
#  'guilt',
#  'thoroughly',
#  'handling',
#  'west',
#  'females',
#  'ranch',
#  'dome',
#  'reduction',
#  'brief',
#  'destroyed',
#  'dry',
#  'Cavalry',
#  'marching',
#  'took',
#  'clergyman',
#  'purity',
#  'meaningless',
#  'queens',
#  'vision',
#  'bunks',
#  'capitalism',
#  'W.',
#  'Carl',
#  'body',
#  'stretched',
#  'assure',
#  'physics',
#  'mild',
#  'include',
#  'hormone',
#  'experimental',
#  'Shea',
#  'artist',
#  'prone',
#  'intend',
#  'triumph',
#  'accuracy',
#  'repeatedly',
#  'tetrachloride',
#  'comparative',
#  'peaceful',
#  'Wagner',
#  'tracing',
#  'entry',
#  'surprised',
#  'prominent',
#  'starting',
#  'traditions',
#  'minute',
#  'tossed',
#  'Pohl',
#  'apprehension',
#  'section',
#  'cap',
#  'epidemic',
#  'year-old',
#  'radio',
#  'pine',
#  'elsewhere',
#  'Room',
#  'spare',
#  'legislators',
#  'vote',
#  'dominance',
#  'fellowship',
#  'testimony',
#  'conditioned',
#  'statement',
#  'games',
#  'polls',
#  'various',
#  'fences',
#  'border',
#  'specified',
#  'prepare',
#  'unemployment',
#  'appreciation',
#  'dignity',
#  'bag',
#  'sidewalk',
#  'Defense',
#  'esprit',
#  'fishing',
#  'accurate',
#  'conduct',
#  'changing',
#  'exposure',
#  ...]

# %%
word2index['<UNK>'] = 0

# %%
#just in case we need to use
index2word = {v:k for k, v in word2index.items()}

# %% [markdown]
# ## 2. Build Co-occurence Matrix X

# %% [markdown]
# Here, we need to count the co-occurence of two words given some window size.  We gonna use window size of 1.

# %%
from collections import Counter

X_i = Counter(flatten(corpus))
X_i
# Out:
# Counter({"''": 4086,
#          '``': 4068,
#          "'s": 2910,
#          'one': 1564,
#          'would': 1533,
#          'said': 1157,
#          "n't": 1069,
#          'could': 948,
#          'time': 834,
#          'two': 739,
#          'may': 709,
#          'man': 681,
#          'like': 673,
#          'first': 667,
#          'made': 586,
#          'also': 571,
#          'new': 569,
#          'must': 556,
#          'back': 536,
#          'years': 521,
#          'many': 495,
#          'even': 495,
#          'much': 475,
#          'way': 475,
#          'Mr.': 472,
#          'good': 449,
#          'f': 446,
#          'people': 445,
#          'make': 441,
#          'little': 433,
#          'year': 425,
#          'get': 405,
#          'work': 395,
#          'long': 395,
#          'see': 388,
#          'men': 386,
#          'well': 380,
#          'still': 376,
#          'world': 365,
#          'us': 352,
#          'might': 346,
#          'last': 346,
#          'life': 343,
#          'day': 342,
#          'take': 337,
#          'know': 337,
#          'go': 333,
#          'never': 332,
#          'came': 327,
#          'around': 319,
#          'state': 314,
#          'another': 314,
#          'three': 312,
#          'old': 309,
#          'place': 307,
#          'great': 307,
#          '1': 305,
#          'American': 297,
#          'come': 297,
#          'used': 293,
#          'home': 290,
#          'small': 290,
#          'right': 288,
#          'use': 286,
#          'found': 278,
#          'New': 273,
#          '2': 272,
#          'left': 271,
#          'without': 267,
#          'high': 266,
#          'away': 266,
#          'went': 259,
#          'got': 257,
#          'thought': 255,
#          'say': 250,
#          'number': 246,
#          "'ll": 246,
#          'every': 245,
#          'Mrs.': 242,
#          'enough': 242,
#          'One': 242,
#          'think': 240,
#          'less': 238,
#          'something': 236,
#          'part': 236,
#          'since': 235,
#          'house': 233,
#          'find': 232,
#          'water': 229,
#          'head': 228,
#          'night': 227,
#          'took': 226,
#          'put': 226,
#          'course': 226,
#          'far': 224,
#          'per': 223,
#          'hand': 223,
#          'toward': 221,
#          'almost': 221,
#          'side': 221,
#          'fact': 220,
#          'going': 217,
#          'always': 216,
#          'school': 213,
#          'area': 212,
#          'system': 211,
#          'program': 210,
#          'give': 210,
#          'better': 210,
#          'however': 209,
#          'become': 206,
#          'form': 205,
#          'point': 205,
#          'things': 204,
#          'children': 202,
#          'possible': 202,
#          'thing': 202,
#          'important': 202,
#          'room': 202,
#          'given': 201,
#          'need': 201,
#          'door': 201,
#          "'d": 200,
#          'present': 199,
#          'set': 199,
#          'group': 199,
#          'knew': 199,
#          'God': 199,
#          'called': 198,
#          'though': 198,
#          'eyes': 198,
#          'days': 197,
#          'next': 196,
#          'end': 195,
#          'told': 195,
#          'public': 193,
#          'second': 193,
#          'face': 192,
#          'large': 191,
#          'felt': 191,
#          'saw': 188,
#          'done': 188,
#          'upon': 187,
#          'family': 187,
#          'light': 186,
#          'four': 185,
#          'least': 185,
#          'nothing': 185,
#          'case': 185,
#          'country': 184,
#          'often': 183,
#          'along': 183,
#          'best': 183,
#          'city': 181,
#          'asked': 181,
#          'turned': 181,
#          'want': 181,
#          'look': 181,
#          'open': 178,
#          'problem': 177,
#          'let': 177,
#          'members': 176,
#          'seemed': 175,
#          'business': 175,
#          'big': 174,
#          'rather': 174,
#          'power': 174,
#          'local': 173,
#          'several': 173,
#          'John': 173,
#          'United': 173,
#          'certain': 172,
#          'later': 172,
#          'feet': 171,
#          'ever': 170,
#          'today': 170,
#          'States': 170,
#          'within': 170,
#          'began': 168,
#          'order': 167,
#          'help': 167,
#          "'re": 166,
#          'general': 165,
#          'social': 165,
#          'early': 163,
#          'week': 161,
#          'young': 161,
#          'different': 160,
#          '3': 159,
#          'half': 159,
#          'experience': 159,
#          'seen': 158,
#          'sense': 157,
#          'either': 157,
#          'whole': 156,
#          'show': 156,
#          '**f': 156,
#          'looked': 155,
#          'past': 154,
#          'information': 154,
#          'across': 154,
#          'war': 154,
#          'kind': 153,
#          'interest': 152,
#          'law': 152,
#          'keep': 152,
#          'government': 152,
#          'ago': 151,
#          'body': 151,
#          'U.': 150,
#          'S.': 150,
#          'field': 150,
#          'car': 150,
#          'President': 149,
#          'among': 148,
#          'taken': 147,
#          'cannot': 147,
#          'five': 147,
#          'gave': 147,
#          'York': 146,
#          'mind': 146,
#          'behind': 146,
#          'wife': 142,
#          'areas': 142,
#          'brought': 141,
#          'real': 141,
#          'really': 141,
#          'seems': 141,
#          'matter': 141,
#          'quite': 141,
#          'others': 141,
#          'line': 140,
#          'history': 140,
#          'yet': 139,
#          'front': 139,
#          'moment': 139,
#          'held': 138,
#          'job': 138,
#          "'ve": 138,
#          'sure': 138,
#          'run': 137,
#          'development': 137,
#          'making': 136,
#          'money': 136,
#          'study': 136,
#          'means': 136,
#          'together': 135,
#          'political': 135,
#          '4': 135,
#          'surface': 135,
#          'death': 134,
#          'close': 134,
#          'already': 134,
#          'started': 134,
#          'top': 133,
#          'times': 133,
#          'human': 133,
#          'action': 132,
#          'question': 132,
#          'tell': 129,
#          'problems': 129,
#          'office': 128,
#          'anything': 128,
#          'company': 128,
#          'result': 127,
#          'State': 127,
#          'child': 127,
#          'boy': 127,
#          'period': 127,
#          'stood': 125,
#          'example': 125,
#          'probably': 124,
#          'air': 124,
#          'able': 123,
#          'turn': 123,
#          'full': 123,
#          'name': 123,
#          'reason': 123,
#          'whether': 122,
#          'national': 122,
#          'individual': 122,
#          'type': 122,
#          'free': 122,
#          'tax': 121,
#          'seem': 121,
#          'change': 121,
#          'town': 121,
#          'woman': 121,
#          'provide': 120,
#          'control': 120,
#          'hands': 120,
#          'became': 119,
#          'says': 119,
#          'word': 119,
#          'major': 119,
#          'words': 119,
#          'minutes': 118,
#          'girl': 118,
#          'mean': 118,
#          'heard': 117,
#          'white': 117,
#          'land': 117,
#          'available': 116,
#          'wanted': 116,
#          'added': 115,
#          'schools': 115,
#          'special': 115,
#          'center': 115,
#          'pressure': 115,
#          'months': 115,
#          'outside': 115,
#          'necessary': 115,
#          'party': 114,
#          'lines': 114,
#          'clear': 114,
#          'feel': 113,
#          'play': 113,
#          '10': 113,
#          'sound': 113,
#          'voice': 113,
#          'position': 112,
#          'situation': 112,
#          'service': 112,
#          'music': 112,
#          'Miss': 112,
#          'known': 112,
#          'space': 111,
#          'America': 111,
#          'needed': 110,
#          'short': 110,
#          'perhaps': 110,
#          'cost': 109,
#          'near': 109,
#          'hard': 109,
#          'mother': 109,
#          'church': 109,
#          'third': 108,
#          'ground': 108,
#          'effect': 107,
#          'board': 107,
#          'community': 107,
#          'cut': 107,
#          'following': 107,
#          'usually': 107,
#          'alone': 107,
#          'However': 106,
#          'believe': 106,
#          'six': 106,
#          'Since': 106,
#          'heart': 106,
#          "'m": 106,
#          'training': 105,
#          'Kennedy': 105,
#          'future': 104,
#          'expected': 104,
#          'road': 104,
#          'Dr.': 104,
#          'living': 104,
#          'feeling': 104,
#          'leave': 104,
#          'modern': 104,
#          'plan': 103,
#          'age': 103,
#          'hours': 103,
#          'true': 103,
#          'material': 103,
#          'idea': 102,
#          'points': 102,
#          'level': 102,
#          'greater': 101,
#          'strong': 101,
#          'West': 101,
#          'various': 101,
#          'evidence': 100,
#          'House': 100,
#          'attention': 100,
#          'total': 100,
#          'shown': 100,
#          'value': 100,
#          'basis': 100,
#          '30': 99,
#          'person': 99,
#          'spirit': 99,
#          'getting': 98,
#          'return': 98,
#          'kept': 98,
#          'military': 98,
#          'moved': 98,
#          'dead': 98,
#          'dark': 98,
#          'makes': 98,
#          'view': 98,
#          'complete': 98,
#          'size': 97,
#          'taking': 97,
#          'tried': 97,
#          'Thus': 97,
#          'Even': 97,
#          'society': 97,
#          'street': 97,
#          'population': 97,
#          'normal': 96,
#          '1960': 96,
#          'million': 95,
#          'wall': 95,
#          'whose': 95,
#          'figure': 95,
#          'hope': 95,
#          'else': 95,
#          'rate': 95,
#          'shall': 95,
#          'inside': 95,
#          'meeting': 94,
#          'soon': 94,
#          'common': 94,
#          'amount': 94,
#          'floor': 94,
#          '5': 93,
#          'increase': 93,
#          'lost': 93,
#          'hour': 93,
#          'reached': 93,
#          'support': 93,
#          'longer': 93,
#          'paper': 93,
#          'South': 93,
#          'art': 93,
#          'coming': 92,
#          'bring': 92,
#          'difficult': 92,
#          'industry': 92,
#          'century': 92,
#          'morning': 92,
#          'needs': 91,
#          '15': 91,
#          'particular': 91,
#          'growth': 91,
#          'piece': 91,
#          'pay': 90,
#          'Washington': 90,
#          'beyond': 90,
#          'picture': 90,
#          'values': 90,
#          'North': 90,
#          'fire': 89,
#          'passed': 89,
#          'hear': 89,
#          'except': 89,
#          'cent': 89,
#          'religious': 89,
#          'call': 89,
#          'states': 89,
#          'father': 89,
#          'equipment': 89,
#          'nature': 89,
#          'sat': 89,
#          'personal': 88,
#          'effort': 88,
#          'Island': 88,
#          'developed': 88,
#          'single': 88,
#          'looking': 88,
#          'husband': 88,
#          'care': 88,
#          'economic': 88,
#          'property': 87,
#          'stage': 87,
#          'low': 87,
#          'C': 87,
#          'miles': 87,
#          'force': 86,
#          'read': 86,
#          'late': 86,
#          'ten': 86,
#          'gone': 86,
#          'especially': 86,
#          'trying': 86,
#          'private': 86,
#          'received': 85,
#          'ready': 85,
#          'start': 85,
#          'lay': 85,
#          'policy': 85,
#          'black': 85,
#          'nation': 85,
#          'sometimes': 85,
#          'although': 84,
#          '8': 84,
#          'St.': 84,
#          'hold': 84,
#          'live': 83,
#          'fine': 83,
#          'addition': 83,
#          '20': 83,
#          'month': 83,
#          'showed': 83,
#          'beginning': 83,
#          'sort': 83,
#          'natural': 83,
#          'conditions': 83,
#          'process': 83,
#          'try': 83,
#          'pool': 83,
#          'act': 82,
#          'opened': 82,
#          'planning': 82,
#          'English': 82,
#          'rest': 82,
#          'everything': 82,
#          'building': 82,
#          '12': 81,
#          'walked': 81,
#          'talk': 81,
#          'hall': 81,
#          'stand': 81,
#          'Let': 81,
#          'fiscal': 81,
#          'aid': 80,
#          'report': 80,
#          'performance': 80,
#          'obtained': 80,
#          'class': 80,
#          'steps': 79,
#          '1961': 79,
#          '6': 79,
#          'National': 79,
#          'season': 79,
#          'range': 79,
#          'placed': 79,
#          'nuclear': 79,
#          'East': 79,
#          'recent': 78,
#          'Department': 78,
#          'required': 78,
#          'move': 78,
#          'followed': 78,
#          'teeth': 78,
#          'love': 78,
#          'Christian': 78,
#          'hundred': 78,
#          'programs': 78,
#          'police': 78,
#          'couple': 77,
#          'color': 77,
#          'summer': 77,
#          'working': 77,
#          'therefore': 77,
#          'particularly': 77,
#          'cold': 77,
#          'simply': 77,
#          'women': 77,
#          'temperature': 77,
#          'higher': 77,
#          'trial': 77,
#          'City': 76,
#          'son': 76,
#          'likely': 76,
#          'horse': 76,
#          'cities': 76,
#          'series': 76,
#          '7': 76,
#          'meet': 76,
#          'difference': 76,
#          'forms': 76,
#          'thus': 76,
#          'carried': 76,
#          'plant': 76,
#          'eye': 76,
#          'sales': 76,
#          'countries': 76,
#          'purpose': 75,
#          'questions': 75,
#          'merely': 75,
#          'wide': 75,
#          'General': 75,
#          'strength': 75,
#          'basic': 75,
#          'bed': 75,
#          'simple': 75,
#          '50': 74,
#          'worked': 74,
#          'students': 74,
#          'anyone': 74,
#          'indicated': 74,
#          'understand': 74,
#          'using': 74,
#          'trees': 74,
#          'fear': 74,
#          'step': 74,
#          'farm': 74,
#          'th': 74,
#          'audience': 73,
#          'similar': 73,
#          'led': 73,
#          'final': 73,
#          'average': 73,
#          'lot': 73,
#          'book': 73,
#          'wrote': 73,
#          'reading': 73,
#          'Soviet': 73,
#          'due': 73,
#          'data': 73,
#          'subject': 72,
#          'concerned': 72,
#          'England': 72,
#          'earth': 72,
#          'quality': 72,
#          'direct': 72,
#          'bad': 72,
#          'forces': 72,
#          'feed': 72,
#          'medical': 71,
#          'cases': 71,
#          'considered': 71,
#          'results': 71,
#          'terms': 71,
#          'education': 70,
#          'corner': 70,
#          'record': 70,
#          'comes': 70,
#          'paid': 70,
#          'gives': 70,
#          'Yet': 70,
#          'closed': 70,
#          'growing': 70,
#          'theory': 70,
#          'Federal': 70,
#          'table': 70,
#          'issue': 69,
#          'trouble': 69,
#          'sent': 69,
#          'degree': 69,
#          'eight': 69,
#          'weeks': 69,
#          'lead': 69,
#          'ran': 69,
#          'suddenly': 69,
#          'knows': 69,
#          'chance': 69,
#          'involved': 69,
#          'larger': 69,
#          'clay': 69,
#          'earlier': 68,
#          'hot': 68,
#          'former': 68,
#          'reported': 68,
#          'arms': 68,
#          'labor': 68,
#          'food': 68,
#          'daily': 68,
#          'covered': 68,
#          'officer': 68,
#          'Many': 67,
#          'decided': 67,
#          'fall': 67,
#          'spring': 67,
#          'boys': 67,
#          'recently': 67,
#          'easy': 67,
#          'entire': 67,
#          'role': 67,
#          'ideas': 67,
#          'physical': 67,
#          'statement': 67,
#          'thinking': 67,
#          'certainly': 67,
#          'literature': 67,
#          'Southern': 67,
#          'method': 67,
#          'stress': 67,
#          'afternoon': 66,
#          'ask': 66,
#          'bit': 66,
#          'serious': 66,
#          'ball': 66,
#          'game': 66,
#          'appeared': 66,
#          'happened': 66,
#          'latter': 66,
#          'foreign': 66,
#          'attitude': 66,
#          'friends': 66,
#          'girls': 66,
#          'completely': 66,
#          'test': 66,
#          'window': 66,
#          'systems': 66,
#          'shot': 65,
#          'doubt': 65,
#          'limited': 65,
#          'weight': 65,
#          'plane': 65,
#          'continued': 65,
#          'ones': 65,
#          'remember': 65,
#          'distance': 65,
#          'changes': 65,
#          'direction': 65,
#          'influence': 65,
#          'instead': 65,
#          'sides': 65,
#          'movement': 65,
#          'manner': 65,
#          'nearly': 65,
#          'actually': 65,
#          'hair': 65,
#          'gun': 64,
#          'Rhode': 64,
#          'hit': 64,
#          'Although': 64,
#          'described': 64,
#          'Mike': 64,
#          'Catholic': 64,
#          'numbers': 64,
#          'Negro': 64,
#          'story': 64,
#          'clearly': 64,
#          'design': 64,
#          'income': 64,
#          'services': 63,
#          'persons': 63,
#          'Another': 63,
#          'efforts': 63,
#          'slowly': 63,
#          'Mercer': 63,
#          'treatment': 63,
#          'member': 63,
#          'written': 63,
#          'peace': 63,
#          'parts': 63,
#          'stop': 63,
#          'exactly': 63,
#          'meaning': 63,
#          'figures': 63,
#          'Lord': 63,
#          'square': 63,
#          'red': 63,
#          'administration': 62,
#          'learned': 62,
#          'generally': 62,
#          'places': 62,
#          'trade': 62,
#          'cause': 62,
#          'approach': 62,
#          'met': 62,
#          'list': 62,
#          'First': 62,
#          'international': 62,
#          'increased': 62,
#          'section': 62,
#          'filled': 62,
#          'effective': 61,
#          'visit': 61,
#          'George': 61,
#          'finally': 61,
#          'college': 61,
#          'volume': 61,
#          'deal': 61,
#          'sun': 61,
#          'neither': 61,
#          'hardly': 61,
#          'types': 61,
#          'lack': 61,
#          'Western': 61,
#          'organization': 61,
#          'War': 61,
#          'knowledge': 61,
#          'patient': 61,
#          'central': 61,
#          'seven': 60,
#          'including': 60,
#          'A.': 60,
#          'immediately': 60,
#          'straight': 60,
#          'running': 60,
#          'film': 60,
#          'production': 60,
#          'understanding': 60,
#          'Church': 60,
#          'heavy': 60,
#          'activity': 60,
#          'radio': 60,
#          'Americans': 60,
#          'responsibility': 60,
#          'cars': 60,
#          'William': 59,
#          'Sunday': 59,
#          'Congress': 59,
#          'Two': 59,
#          'entered': 59,
#          'playing': 59,
#          'leaders': 59,
#          'scene': 59,
#          'drive': 59,
#          'arm': 59,
#          '25': 59,
#          'easily': 59,
#          'wrong': 59,
#          'gas': 59,
#          'demand': 59,
#          'share': 59,
#          'directly': 59,
#          'ship': 59,
#          'pieces': 59,
#          'friend': 59,
#          'designed': 58,
#          'served': 58,
#          'dropped': 58,
#          'moving': 58,
#          'Union': 58,
#          'works': 58,
#          'stock': 58,
#          'pattern': 58,
#          'evening': 58,
#          'throughout': 58,
#          'highly': 58,
#          'lower': 58,
#          'radiation': 58,
#          'religion': 58,
#          '1958': 57,
#          'bill': 57,
#          'operation': 57,
#          'saying': 57,
#          'manager': 57,
#          'forward': 57,
#          'reasons': 57,
#          'Perhaps': 57,
#          'appear': 57,
#          'somewhat': 57,
#          'market': 57,
#          'Khrushchev': 57,
#          'Well': 57,
#          'answer': 57,
#          'waiting': 57,
#          'function': 57,
#          'expect': 57,
#          'pain': 57,
#          'born': 57,
#          'determined': 57,
#          'shelter': 57,
#          'Communist': 57,
#          'date': 56,
#          'continue': 56,
#          'additional': 56,
#          'doctor': 56,
#          'race': 56,
#          '100': 56,
#          'University': 56,
#          'prepared': 56,
#          'finished': 56,
#          'played': 56,
#          'professional': 56,
#          'green': 56,
#          'raised': 56,
#          'reaction': 56,
#          'Secretary': 56,
#          'note': 56,
#          'churches': 56,
#          'main': 56,
#          'built': 56,
#          'letter': 56,
#          'caught': 56,
#          'cells': 56,
#          'mouth': 56,
#          'price': 56,
#          'according': 55,
#          'session': 55,
#          'fight': 55,
#          'foot': 55,
#          'successful': 55,
#          'practice': 55,
#          'happy': 55,
#          'ahead': 55,
#          'stopped': 55,
#          'concern': 55,
#          'blood': 55,
#          'French': 55,
#          'shows': 55,
#          'heat': 55,
#          'reach': 55,
#          'groups': 55,
#          'faith': 55,
#          'original': 55,
#          'specific': 55,
#          'bar': 55,
#          'firm': 55,
#          'include': 55,
#          'thin': 55,
#          'analysis': 55,
#          'marriage': 55,
#          'costs': 54,
#          'lived': 54,
#          'plans': 54,
#          'choice': 54,
#          'methods': 54,
#          'subjects': 54,
#          'White': 54,
#          'truth': 54,
#          'beautiful': 54,
#          'account': 54,
#          'moral': 54,
#          'effects': 54,
#          'edge': 54,
#          'charge': 54,
#          'suggested': 54,
#          'kitchen': 54,
#          'B': 54,
#          'bridge': 54,
#          'consider': 54,
#          'Government': 54,
#          'anode': 54,
#          'complex': 54,
#          'hotel': 54,
#          'serve': 53,
#          'attack': 53,
#          'C.': 53,
#          'attempt': 53,
#          'unit': 53,
#          'returned': 53,
#          '1959': 53,
#          'May': 53,
#          'round': 53,
#          'current': 53,
#          'based': 53,
#          'established': 53,
#          'principle': 53,
#          'changed': 53,
#          'add': 53,
#          'standard': 53,
#          'significant': 53,
#          'm.': 53,
#          'previous': 52,
#          'married': 52,
#          'J.': 52,
#          'announced': 52,
#          'determine': 52,
#          'marked': 52,
#          'March': 52,
#          'apparently': 52,
#          'letters': 52,
#          'project': 52,
#          'president': 52,
#          'fell': 52,
#          'respect': 52,
#          'fixed': 52,
#          'research': 52,
#          'meant': 52,
#          'existence': 52,
#          'image': 52,
#          'balance': 52,
#          'importance': 52,
#          'energy': 52,
#          'cell': 52,
#          'laws': 51,
#          'construction': 51,
#          'Charles': 51,
#          'middle': 51,
#          'obvious': 51,
#          'remained': 51,
#          'ways': 51,
#          'leadership': 51,
#          'glass': 51,
#          'separate': 51,
#          'Berlin': 51,
#          'British': 51,
#          'extent': 51,
#          'build': 51,
#          'looks': 51,
#          'rise': 51,
#          'break': 51,
#          'collection': 51,
#          'election': 50,
#          'none': 50,
#          'dollars': 50,
#          'James': 50,
#          'student': 50,
#          'explained': 50,
#          'Mary': 50,
#          'decision': 50,
#          'style': 50,
#          'speak': 50,
#          'Chicago': 50,
#          'flow': 50,
#          'provided': 50,
#          'wish': 50,
#          'Jewish': 50,
#          'techniques': 50,
#          'sea': 50,
#          'aircraft': 50,
#          'funds': 49,
#          'technical': 49,
#          'spent': 49,
#          'poor': 49,
#          'blue': 49,
#          'pretty': 49,
#          'Old': 49,
#          'length': 49,
#          'Jack': 49,
#          'staff': 49,
#          ...})

# %%
window_size = 5

def random_batch(corpus, window_size=2):
    skip_grams = []

    for doc in corpus:
        for i in range(window_size, len(doc)-window_size):
            center = doc[i]
            # endpoints of the window
            outside_start =  i - window_size
            outside_end =  i + window_size + 1

            for j in range(outside_start, outside_end):
                if i != j:  # Skip the center word
                    outside = doc[j]
                    skip_grams.append((center, outside))

            return skip_grams
        
skip_grams = random_batch(corpus, window_size)

# %%
X_ik_skipgrams = Counter(skip_grams)
X_ik_skipgrams
# Out:
# Counter({('investigation', 'Fulton'): 1,
#          ('investigation', 'County'): 1,
#          ('investigation', 'Grand'): 1,
#          ('investigation', 'said'): 1,
#          ('investigation', 'Friday'): 1,
#          ('investigation', 'Atlanta'): 1,
#          ('investigation', "'s"): 1,
#          ('investigation', 'recent'): 1,
#          ('investigation', 'primary'): 1,
#          ('investigation', 'election'): 1})

# %% [markdown]
# ### Weighting function
#
# GloVe includes a weighting function to scale down too frequent words.
#
# <img src = "../figures/glove_weighting_func.png" width=400>

# %%
def weighting(w_i, w_j, X_ik):
    
    #check whether the co-occurences between w_i and w_j is available
    try:
        x_ij = X_ik[(w_i, w_j)]
        #if not exist, then set to 1 "laplace smoothing"
    except:
        x_ij = 1
        
    #set xmax
    x_max = 100
    #set alpha
    alpha = 0.75
    
    #if co-ocurrence does not exceeed xmax, then just multiply with some alpha
    if x_ij < x_max:
        result = (x_ij / x_max)**alpha
    #otherwise, set to 1
    else:
        result = 1
    
    return result

# %%
from itertools import combinations_with_replacement

X_ik = {} #keeping the co-occurences
weighting_dic = {} #already scale the co-occurences using the weighting function

for bigram in combinations_with_replacement(vocab, 2):
    if X_ik_skipgrams.get(bigram):  #if the pair exists in our corpus
        co = X_ik_skipgrams[bigram]
        X_ik[bigram] = co + 1 #for stability
        X_ik[(bigram[1], bigram[0])] = co + 1 #basically apple, banana = banana, apple
    else:
        pass
    
    weighting_dic[bigram] = weighting(bigram[0], bigram[1], X_ik)
    weighting_dic[(bigram[1], bigram[0])] = weighting(bigram[1], bigram[0], X_ik)

# %% [markdown]
# ## 3. Prepare train data

# %%
import math

def random_batch(batch_size, word_sequence, skip_grams, X_ik, weighting_dic):
    
    random_inputs, random_labels, random_coocs, random_weightings = [], [], [], []
    
    #convert our skipgrams to id
    skip_grams_id = [(word2index[skip_gram[0]], word2index[skip_gram[1]]) for skip_gram in skip_grams]
    
    #randomly choose indexes based on batch size
    random_index = np.random.choice(range(len(skip_grams_id)), batch_size, replace=False)
    
    #get the random input and labels
    for index in random_index:
        random_inputs.append([skip_grams_id[index][0]])
        random_labels.append([skip_grams_id[index][1]])
        #coocs
        pair = skip_grams[index] #e.g., ('banana', 'fruit')
        try:
            cooc = X_ik[pair]
        except:
            cooc = 1
        random_coocs.append([math.log(cooc)])
    
        #weightings
        weighting = weighting_dic[pair]
        random_weightings.append([weighting])
        
    return np.array(random_inputs), np.array(random_labels), np.array(random_coocs), np.array(random_weightings)

# %% [markdown]
# ### Testing the method

# %%
batch_size = 2
x, y, cooc, weighting = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)

# %%
x
# Out:
# array([[4856],
#        [4856]])

# %%
y
# Out:
# array([[2546],
#        [4988]])

# %%
cooc
# Out:
# array([[0.        ],
#        [0.69314718]])

# %%
weighting
# Out:
# array([[0.03162278],
#        [0.05318296]])

# %% [markdown]
# ## 4. Model
#
# <img src ="../figures/glove.png" width=400>

# %%
class Glove(nn.Module):
    
    def __init__(self, voc_size, emb_size):
        super(Glove, self).__init__()
        self.center_embedding  = nn.Embedding(voc_size, emb_size)
        self.outside_embedding = nn.Embedding(voc_size, emb_size)
        
        self.center_bias       = nn.Embedding(voc_size, 1) 
        self.outside_bias      = nn.Embedding(voc_size, 1)
    
    def forward(self, center, outside, coocs, weighting):
        center_embeds  = self.center_embedding(center) #(batch_size, 1, emb_size)
        outside_embeds = self.outside_embedding(outside) #(batch_size, 1, emb_size)
        
        center_bias    = self.center_bias(center).squeeze(1)
        target_bias    = self.outside_bias(outside).squeeze(1)
        
        inner_product  = outside_embeds.bmm(center_embeds.transpose(1, 2)).squeeze(2)
        #(batch_size, 1, emb_size) @ (batch_size, emb_size, 1) = (batch_size, 1, 1) = (batch_size, 1)
        
        loss = weighting * torch.pow(inner_product + center_bias + target_bias - coocs, 2)
        
        return torch.sum(loss)

# %%
#test our system
voc_size = len(vocab)
emb_size = 2
model = Glove(voc_size, emb_size)

# %%
x_tensor = torch.LongTensor(x)
y_tensor = torch.LongTensor(y)
cooc_tensor = torch.FloatTensor(cooc)
weighting_tensor = torch.FloatTensor(weighting)

# %%
loss = model(x_tensor, y_tensor, cooc_tensor, weighting_tensor)

# %%
loss
# Out:
# tensor(0.0630, grad_fn=<SumBackward0>)

# %% [markdown]
# ## 5. Training

# %%
batch_size     = 10 # mini-batch size
embedding_size = 2 #so we can later plot
model          = Glove(voc_size, embedding_size)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

# %%
import time

# Training
num_epochs = 100
for epoch in range(num_epochs):
    
    start = time.time()
    
    input_batch, target_batch, cooc_batch, weighting_batch = random_batch(batch_size, corpus, skip_grams, X_ik, weighting_dic)
    input_batch  = torch.LongTensor(input_batch)         #[batch_size, 1]
    target_batch = torch.LongTensor(target_batch)        #[batch_size, 1]
    cooc_batch   = torch.FloatTensor(cooc_batch)         #[batch_size, 1]
    weighting_batch = torch.FloatTensor(weighting_batch) #[batch_size, 1]
    
    optimizer.zero_grad()
    loss = model(input_batch, target_batch, cooc_batch, weighting_batch)
    
    loss.backward()
    optimizer.step()
    
    end = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start, end)

    if (epoch + 1) % 10 == 0:
        print(f"Epoch: {epoch + 1} | cost: {loss:.6f} | time: {epoch_mins}m {epoch_secs}s")
# Out:
# Epoch: 10 | cost: 0.596864 | time: 0m 0s
# Epoch: 20 | cost: 0.573665 | time: 0m 0s
# Epoch: 30 | cost: 0.551771 | time: 0m 0s
# Epoch: 40 | cost: 0.531193 | time: 0m 0s
# Epoch: 50 | cost: 0.511891 | time: 0m 0s
# Epoch: 60 | cost: 0.493793 | time: 0m 0s
# Epoch: 70 | cost: 0.476816 | time: 0m 0s
# Epoch: 80 | cost: 0.460870 | time: 0m 0s
# Epoch: 90 | cost: 0.445870 | time: 0m 0s
# Epoch: 100 | cost: 0.431736 | time: 0m 0s

# %% [markdown]
# ## 6. Plotting the embeddings

# %%
#list of vocabs
vocab[:10]
# Out:
# ['kept',
#  'gate',
#  'featured',
#  'servants',
#  'roots',
#  'clerk',
#  'Black',
#  'partial',
#  "o'clock",
#  'chairs']

# %%
word = vocab[0]

# %%
#numericalization
id = word2index[word]
id
# Out:
# 0

# %%
id_tensor = torch.LongTensor([id])
id_tensor
# Out:
# tensor([0])

# %%
#get the embedding by averaging
v_embed = model.center_embedding(id_tensor)
u_embed = model.outside_embedding(id_tensor)

v_embed, u_embed
# Out:
# (tensor([[ 0.0508, -1.6715]], grad_fn=<EmbeddingBackward0>),
#  tensor([[0.3629, 0.5799]], grad_fn=<EmbeddingBackward0>))

# %%
#average to get the word embedding
word_embed = (v_embed + u_embed) / 2
word_embed
# Out:
# tensor([[ 0.2068, -0.5458]], grad_fn=<DivBackward0>)

# %%
#let's write a function to get embedding given a word
def get_embed(word):
    id_tensor = torch.LongTensor([word2index[word]])
    v_embed = model.center_embedding(id_tensor)
    u_embed = model.outside_embedding(id_tensor) 
    word_embed = (v_embed + u_embed) / 2 
    x, y = word_embed[0][0].item(), word_embed[0][1].item()

    return x, y

# %% [markdown]
# ## 7. Cosine similarity
#
# Formally the [Cosine Similarity](https://en.wikipedia.org/wiki/Cosine_similarity) $s$ between two vectors $p$ and $q$ is defined as:
#
# $$s = \frac{p \cdot q}{||p|| ||q||}, \textrm{ where } s \in [-1, 1] $$
#
# If $p$ and $q$ is super similar, the result is 1 otherwise 0.

# %%
vocab
# Out:
# ['kept',
#  'gate',
#  'featured',
#  'servants',
#  'roots',
#  'clerk',
#  'Black',
#  'partial',
#  "o'clock",
#  'chairs',
#  'Ca',
#  'observers',
#  'concerning',
#  'proof',
#  'disposed',
#  'wages',
#  'machine',
#  'Masters',
#  'alone',
#  'output',
#  'masses',
#  'owner',
#  'Day',
#  'peak',
#  'worth',
#  'line',
#  'female',
#  'Trig',
#  'consciously',
#  'Quite',
#  'walking',
#  'technology',
#  'connections',
#  'permits',
#  'Greg',
#  'least',
#  'shadows',
#  'boots',
#  'parents',
#  'Country',
#  'prevent',
#  'per',
#  'pilot',
#  'rank',
#  'preceded',
#  'staring',
#  'advocate',
#  'territorial',
#  'tune',
#  '1958',
#  'delay',
#  'strand',
#  'Beyond',
#  'stem',
#  'tube',
#  'appearing',
#  'stretch',
#  'brains',
#  'doctrine',
#  'square',
#  'proclaimed',
#  'Congolese',
#  'mere',
#  'sources',
#  'swiftly',
#  'Russian',
#  'combat',
#  'technical',
#  'official',
#  'wealth',
#  'fool',
#  '50',
#  'workshop',
#  'mountains',
#  'tailored',
#  'Southeast',
#  'caused',
#  'energetic',
#  'engines',
#  'spend',
#  'rocks',
#  'tangent',
#  'Go',
#  'Never',
#  'Force',
#  'shooting',
#  'events',
#  'Certain',
#  'accounts',
#  'classical',
#  'arrive',
#  'Du',
#  'symbolism',
#  'assumption',
#  'assert',
#  'reserve',
#  'loan',
#  'wall',
#  'depth',
#  'Oersted',
#  'milk',
#  'Colorado',
#  'Gilborn',
#  'fiscal',
#  'nation',
#  'meet',
#  'rent',
#  'regarding',
#  'lose',
#  'deserted',
#  'push',
#  'placed',
#  'biggest',
#  'repair',
#  'street',
#  'purchases',
#  'content',
#  'grounds',
#  'F',
#  'seen',
#  'actor',
#  'Clark',
#  'maturity',
#  'touching',
#  'punished',
#  'school',
#  'aim',
#  'Fire',
#  'nineteenth-century',
#  'formally',
#  'deliberately',
#  'writer',
#  'denomination',
#  'campaign',
#  'Kremlin',
#  'long-term',
#  'approximate',
#  'cows',
#  'bullet',
#  'Professor',
#  'discharge',
#  'threatening',
#  'tray',
#  'humor',
#  'burden',
#  'foremost',
#  'matters',
#  'planet',
#  'mg.',
#  'import',
#  'rifles',
#  'becoming',
#  'evidently',
#  'fiery',
#  'authorities',
#  'pump',
#  'pulls',
#  'interrupted',
#  'fit',
#  'salesmen',
#  'coat',
#  'Bonn',
#  'avoiding',
#  'beach',
#  'Harry',
#  'hear',
#  'Providence',
#  '80',
#  'ratings',
#  'acceptance',
#  'client',
#  'processes',
#  'relations',
#  'cleaning',
#  'along',
#  'name',
#  'Friends',
#  'entering',
#  'glorious',
#  'slug',
#  'Sometimes',
#  'volunteers',
#  'clinical',
#  'needs',
#  'learning',
#  'remove',
#  'terraces',
#  'working',
#  'superior',
#  'Blue',
#  'wisely',
#  'effects',
#  'commented',
#  'sister',
#  'news',
#  'lift',
#  'controls',
#  'deposited',
#  'Powell',
#  'truth',
#  'badly',
#  'skills',
#  'agency',
#  'well-being',
#  'wastes',
#  'Russians',
#  'Catholic',
#  'magic',
#  'materials',
#  'voters',
#  'advised',
#  'contest',
#  'runs',
#  'troops',
#  'Bake',
#  'measured',
#  'compared',
#  'lungs',
#  'severe',
#  'unnecessary',
#  'definitely',
#  'guard',
#  'nine',
#  'funds',
#  'Administration',
#  'ritual',
#  'neglected',
#  'country',
#  'usefulness',
#  'organize',
#  'registration',
#  'even',
#  'sea',
#  'Depot',
#  'unconscious',
#  'supper',
#  '1500',
#  'comments',
#  'tomorrow',
#  'Section',
#  'Matson',
#  'Hence',
#  'animals',
#  'Papa-san',
#  'gm.',
#  'interval',
#  'reserved',
#  'rack',
#  'Either',
#  'nowhere',
#  'house',
#  'lane',
#  'rule',
#  'temple',
#  '30',
#  'future',
#  'Springs',
#  'kitchen',
#  '1962',
#  'trip',
#  'placement',
#  'fearful',
#  'Accordingly',
#  'chicken',
#  'trail',
#  'mess',
#  'Warsaw',
#  'bedroom',
#  'knee',
#  'Fighting',
#  'coals',
#  'company',
#  'thigh',
#  'Conrad',
#  'moral',
#  'national',
#  'goods',
#  'Richmond',
#  'golf',
#  'walk',
#  'dogs',
#  'Presently',
#  'guarantees',
#  'heights',
#  'army',
#  'Finally',
#  'instrument',
#  'different',
#  'intention',
#  'attempting',
#  'chambers',
#  'shall',
#  'justice',
#  'Gardens',
#  'becomes',
#  'opens',
#  'diminished',
#  'proposed',
#  'represent',
#  'train',
#  'considerable',
#  'avocado',
#  'outcomes',
#  'union',
#  'Death',
#  'agreed',
#  'Besides',
#  'clue',
#  'shame',
#  'shoulders',
#  'H.',
#  'luncheon',
#  'earning',
#  'witness',
#  'force',
#  'specialists',
#  'gives',
#  'blooming',
#  'resolved',
#  'score',
#  'pertinent',
#  'teaching',
#  'nerve',
#  'message',
#  'place',
#  'involution',
#  'Flannagan',
#  'creates',
#  'add',
#  'lawyer',
#  'theological',
#  'wood',
#  'cannot',
#  'specific',
#  'Daniel',
#  'south',
#  'threatened',
#  'assign',
#  'alive',
#  'mining',
#  'dreadful',
#  'Pam',
#  'automobile',
#  'principle',
#  'Foods',
#  'forgiveness',
#  'impersonal',
#  'promised',
#  'Keys',
#  'middle',
#  'single',
#  'maker',
#  'l',
#  'fists',
#  'stirred',
#  'task',
#  'parked',
#  'weary',
#  'Cranston',
#  'clarity',
#  'fixed',
#  'upright',
#  'sun',
#  'Lee',
#  'Fund',
#  'superstition',
#  'commanded',
#  'adults',
#  'Others',
#  'mathematical',
#  'tanks',
#  'pot',
#  'conceive',
#  'guide',
#  'prospects',
#  'Capone',
#  'forces',
#  'airfields',
#  'advice',
#  'draped',
#  'increases',
#  'butter',
#  'districts',
#  'Also',
#  'O.',
#  'rags',
#  'block',
#  'send',
#  'African',
#  '65',
#  'cotton',
#  'shipping',
#  'lands',
#  'earth',
#  'display',
#  'briefly',
#  'Pa',
#  'succeeded',
#  'huge',
#  'Pastern',
#  'Kahler',
#  'sketch',
#  'spirit',
#  'Sergeant',
#  'debate',
#  'nursery',
#  'hat',
#  'slightest',
#  'amounts',
#  'inner',
#  'engineer',
#  'fig.',
#  'arched',
#  'tooth',
#  'nuclear',
#  'heart',
#  'power',
#  '34',
#  'conducted',
#  'equation',
#  'Apparently',
#  'sweat',
#  'Moliere',
#  'Perhaps',
#  'p',
#  'collecting',
#  'delivering',
#  'Council',
#  'conference',
#  'horse',
#  'seemingly',
#  'carriers',
#  'heaven',
#  'talks',
#  'baked',
#  'appeals',
#  'presence',
#  'causes',
#  'afternoons',
#  'Jews',
#  'domination',
#  'survive',
#  'everyone',
#  'decades',
#  'jam',
#  'theologians',
#  'attached',
#  'graph',
#  'fees',
#  'series',
#  'census',
#  'hated',
#  'Madden',
#  'regular',
#  'rot',
#  'breath',
#  'congregation',
#  'authors',
#  '28',
#  '11',
#  'wars',
#  'ages',
#  'platoon',
#  'consistency',
#  'fled',
#  'unusually',
#  'asserted',
#  'supposed',
#  'cement',
#  'completed',
#  'Pamela',
#  'appealing',
#  'Skyros',
#  'artists',
#  'bartender',
#  "'re",
#  'residents',
#  'Napoleon',
#  'films',
#  'words',
#  'scale',
#  'Special',
#  'foot',
#  'nutrition',
#  'ultimate',
#  'guns',
#  'Communists',
#  'sprang',
#  'spreading',
#  'closely',
#  'U',
#  'Fathers',
#  'tactics',
#  'Barton',
#  'Junior',
#  'exchange',
#  'P.',
#  'Ireland',
#  'noble',
#  'stove',
#  'Greenwich',
#  'commission',
#  'momentum',
#  'plowing',
#  'pastors',
#  'crown',
#  'Bishop',
#  'glued',
#  'doorway',
#  'Clayton',
#  'polished',
#  'neither',
#  'poured',
#  'Marine',
#  'hesitated',
#  'Ferguson',
#  'youngest',
#  'bought',
#  'straightened',
#  'remember',
#  'sensitive',
#  'clearer',
#  'policies',
#  'late',
#  'waited',
#  'University',
#  'items',
#  'Rogers',
#  'Geneva',
#  'dikkat',
#  'persisted',
#  'shapes',
#  'tends',
#  'crashed',
#  'arrived',
#  'livestock',
#  'feelings',
#  'Lord',
#  'Northern',
#  'nose',
#  'meeting',
#  'suits',
#  'sense',
#  'Pittsburgh',
#  'producer',
#  'financially',
#  'Anglican',
#  'kicked',
#  'White',
#  'Orchestra',
#  'pleading',
#  'Earth',
#  'pretending',
#  'avoided',
#  'normally',
#  'unexpected',
#  'swim',
#  'agencies',
#  'straw',
#  'cutting',
#  'gently',
#  'SAC',
#  'week',
#  'helping',
#  'swift',
#  'daylight',
#  'innocent',
#  'displacement',
#  'hearing',
#  'Southern',
#  'right',
#  'eccentric',
#  '10',
#  'symbols',
#  'however',
#  'fitting',
#  'adjustment',
#  'adjusting',
#  'Japan',
#  'portion',
#  'trusted',
#  'lousy',
#  'realize',
#  'fork',
#  'pressure',
#  'standing',
#  'guests',
#  'alternate',
#  'encounter',
#  'Completion',
#  'Reverend',
#  'tree',
#  'beginning',
#  'mad',
#  'medical',
#  'North',
#  'people',
#  'p.',
#  'Joel',
#  'partners',
#  'patterns',
#  'admiration',
#  'veto',
#  'legal',
#  'marked',
#  'orientation',
#  'American',
#  'conscientious',
#  'procedures',
#  'breaking',
#  'members',
#  'philosophy',
#  'Temple',
#  'Island',
#  'dresses',
#  'Methodist',
#  'knowledge',
#  'memories',
#  'lay',
#  'Negroes',
#  '40000',
#  'Heaven',
#  'compare',
#  'Elizabeth',
#  'stained',
#  'museum',
#  'Journal',
#  'Kohnstamm',
#  'flooded',
#  'gifts',
#  'obtaining',
#  'pains',
#  'Australia',
#  'Morton',
#  'printed',
#  'drops',
#  'command',
#  'DEAE-cellulose',
#  'reliable',
#  'replaced',
#  'grown',
#  'projects',
#  'International',
#  'sit',
#  'tropical',
#  'continuously',
#  'credited',
#  'happen',
#  'steadily',
#  'Southwest',
#  'visit',
#  'Every',
#  'secretary',
#  'dancer',
#  'beatnik',
#  'Louis',
#  '6',
#  'scholarship',
#  'forty',
#  'carefully',
#  'threats',
#  'president',
#  'organic',
#  'animal',
#  'adopted',
#  'failing',
#  'paused',
#  '58',
#  'hundreds',
#  'hut',
#  'graduation',
#  'television',
#  'revenue',
#  'heard',
#  'relationship',
#  'supreme',
#  'appearances',
#  'exhibits',
#  'orbit',
#  'shoved',
#  'demographic',
#  'claimed',
#  'insights',
#  'courts',
#  'invitations',
#  'separation',
#  'satisfy',
#  'victims',
#  'equal',
#  'sponsors',
#  'killed',
#  'smile',
#  'Bar',
#  'investors',
#  'builders',
#  'Bears',
#  'directors',
#  'whip',
#  'tests',
#  'expedition',
#  'Picasso',
#  'Cologne',
#  'match',
#  'hurry',
#  'Valley',
#  'welcomed',
#  'slipped',
#  'Word',
#  'economic',
#  'agent',
#  'pan',
#  'streams',
#  'violin',
#  'moved',
#  'way',
#  'farther',
#  'silent',
#  'proposal',
#  'picking',
#  'cherished',
#  'hand',
#  'River',
#  'cooler',
#  'surely',
#  'differentiation',
#  'administrative',
#  'prevention',
#  'implicit',
#  'medicine',
#  'suburban',
#  'twist',
#  'transducer',
#  'acts',
#  'limp',
#  'Otherwise',
#  'talents',
#  'deserved',
#  'overnight',
#  'Missouri',
#  'Billy',
#  'ranks',
#  'Middle',
#  'discourage',
#  'followed',
#  'passion',
#  'faculty',
#  'January',
#  'outboard',
#  'stage',
#  'purpose',
#  'danger',
#  'Eileen',
#  'resulting',
#  'coupled',
#  'formulated',
#  'terribly',
#  '1930',
#  'Larkin',
#  'dependent',
#  'cooling',
#  'request',
#  'function',
#  'justified',
#  'belongs',
#  'changed',
#  'copies',
#  'roll',
#  'incredibly',
#  'Scott',
#  'tsunami',
#  'burned',
#  'resident',
#  'mentally',
#  'story',
#  'wild',
#  'rushed',
#  'salvation',
#  'prestige',
#  'tearing',
#  'grin',
#  '1944',
#  'reporter',
#  'angle',
#  'group',
#  'Society',
#  'dropping',
#  'nature',
#  'sitter',
#  'storage',
#  'York',
#  'playing',
#  'fingers',
#  'Westminster',
#  'children',
#  'administration',
#  'Q',
#  'label',
#  'sincere',
#  'poem',
#  'beebread',
#  'climbed',
#  'London',
#  'enormous',
#  'yielded',
#  'elephants',
#  'thyroid',
#  'victim',
#  'TSH',
#  'dried',
#  'distribution',
#  'v.',
#  'first',
#  'sturdy',
#  'Biblical',
#  'cope',
#  'facts',
#  'instrumental',
#  '3000',
#  'one',
#  'past',
#  'backs',
#  'discover',
#  'peas',
#  'handed',
#  'undoubtedly',
#  'returning',
#  'deaf',
#  '26',
#  'makes',
#  'core',
#  'turnpikes',
#  'independently',
#  'binomial',
#  'assistant',
#  'divisions',
#  'see',
#  'letting',
#  'Doctor',
#  'growing',
#  'hands',
#  'Premier',
#  'Barnett',
#  'Dallas',
#  'Indeed',
#  'legitimate',
#  'oriented',
#  'missions',
#  'dangers',
#  'latest',
#  'Atlantic',
#  'fundamental',
#  'anyhow',
#  'masterpiece',
#  'piece',
#  'Alfred',
#  'protective',
#  'guilty',
#  'whiskey',
#  'opening',
#  'given',
#  'singers',
#  'convenient',
#  'struggling',
#  'site',
#  'uncertainty',
#  'portable',
#  'H',
#  'wound',
#  'told',
#  'instantly',
#  'gentleman',
#  'unfair',
#  'carry',
#  'temperature',
#  'sentences',
#  'attorney',
#  'rock',
#  'comment',
#  'Islands',
#  'Giants',
#  'replacement',
#  'obliged',
#  'exports',
#  'necessarily',
#  'producers',
#  'print',
#  'muddy',
#  'Figure',
#  'sales',
#  'Beckett',
#  'vigor',
#  'observer',
#  'networks',
#  'utterly',
#  'result',
#  'going',
#  'develops',
#  'cooperative',
#  'service',
#  'Shayne',
#  'professor',
#  'absolute',
#  'fog',
#  'barn',
#  'cure',
#  'commitments',
#  'stay',
#  'bomb',
#  'baby',
#  'war',
#  'qualified',
#  'quarrel',
#  'Men',
#  'guilt',
#  'thoroughly',
#  'handling',
#  'west',
#  'females',
#  'ranch',
#  'dome',
#  'reduction',
#  'brief',
#  'destroyed',
#  'dry',
#  'Cavalry',
#  'marching',
#  'took',
#  'clergyman',
#  'purity',
#  'meaningless',
#  'queens',
#  'vision',
#  'bunks',
#  'capitalism',
#  'W.',
#  'Carl',
#  'body',
#  'stretched',
#  'assure',
#  'physics',
#  'mild',
#  'include',
#  'hormone',
#  'experimental',
#  'Shea',
#  'artist',
#  'prone',
#  'intend',
#  'triumph',
#  'accuracy',
#  'repeatedly',
#  'tetrachloride',
#  'comparative',
#  'peaceful',
#  'Wagner',
#  'tracing',
#  'entry',
#  'surprised',
#  'prominent',
#  'starting',
#  'traditions',
#  'minute',
#  'tossed',
#  'Pohl',
#  'apprehension',
#  'section',
#  'cap',
#  'epidemic',
#  'year-old',
#  'radio',
#  'pine',
#  'elsewhere',
#  'Room',
#  'spare',
#  'legislators',
#  'vote',
#  'dominance',
#  'fellowship',
#  'testimony',
#  'conditioned',
#  'statement',
#  'games',
#  'polls',
#  'various',
#  'fences',
#  'border',
#  'specified',
#  'prepare',
#  'unemployment',
#  'appreciation',
#  'dignity',
#  'bag',
#  'sidewalk',
#  'Defense',
#  'esprit',
#  'fishing',
#  'accurate',
#  'conduct',
#  'changing',
#  'exposure',
#  ...]

# %%
#let's try similarity between first and second, and second and third
cat          = get_embed('cat')
fruit        = get_embed('fruit')
animal       = get_embed('animal')

# %%
#numpy version
from numpy import dot
from numpy.linalg import norm

def cos_sim(a, b):
    cos_sim = dot(a, b)/(norm(a)*norm(b))
    return cos_sim
    
print(f"cat vs. fruit: ",        cos_sim(cat, fruit))
print(f"cat vs. animal: ",       cos_sim(cat, animal))
print(f"cat vs. cat: ",          cos_sim(cat, cat))
# Out:
# cat vs. fruit:  -0.42989645515882857
# cat vs. animal:  0.9463488105041457
# cat vs. cat:  1.0000000000000002

# %%
#scipy version
from scipy import spatial

def cos_sim(a, b):
    cos_sim = 1 - spatial.distance.cosine(a, b)  #distance = 1 - similarlity, because scipy only gives distance
    return cos_sim

print(f"cat vs. fruit: ",        cos_sim(cat, fruit))
print(f"cat vs. animal: ",       cos_sim(cat, animal))
print(f"cat vs. cat: ",          cos_sim(cat, cat))
# Out:
# cat vs. fruit:  -0.4298964551588287
# cat vs. animal:  0.9463488105041455
# cat vs. cat:  1.0

# %% [markdown]
# ## Export Model

# %%
import pickle

# %%
filename = 'glove_model.pkl'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ## Export word2index and index2word

# %%
pickle.dump(word2index, open('glove_word2index.pkl', 'wb'))
pickle.dump(index2word, open('glove_index2word.pkl', 'wb'))

# %% [markdown]
# ## Syntactic and Semantic accuracy
